# %% [markdown]
# <a href="https://colab.research.google.com/github/flavionakao/Ling-de-Prog-para-Ciencia-de-Dados/blob/main/TRILHA1_FLAVIONAKAO.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Trilha 1 -
# Para execução desta tarefa, escolhi uma artigo sobre Bigdata.

# %%
import urllib.request  

texto = []

for line in urllib.request.urlopen('https://raw.githubusercontent.com/flavionakao/trilha1/main/artigo%20bigdata.txt'): 
    texto.append(line.decode('utf-8'))

 # f = open('/content/artigo bigdata.txt','r')    # para arquivos locais
 #for line in f:
 #   texto.append(line)

for i in range(len(texto)):
    texto[i] = texto[i].lower() # para unicidade
    texto[i] = texto[i].replace('\n','')
    texto[i] = texto[i].replace('.','')
    texto[i] = texto[i].replace(',','')
    texto[i] = texto[i].replace('(','')
    texto[i] = texto[i].replace(')','')
    texto[i] = texto[i].replace('?','')
    texto[i] = texto[i].replace('\'','') # elimina ' e "

# %%
mydict = {}                             # crie um dicionário vazio

for line in texto:

  line = line.lower()                   # converte para lower
  words = line.split()                  # separa cada palavra
#  print(words)

  for word in words:                      # para cada palavra em words
    if word not in mydict.keys():         # se palavra não está no dicionário 
      mydict[word] = 1                    # acrescenta a word com o valor 1
    else:                                 # se a entrada já existe 
      mydict[word] =  mydict[word] + 1    # apenas soma 1 ao valor já existente

print(mydict)
# Out:
# {'uso': 20, 'corporativo': 6, 'do': 67, 'big': 74, 'data:': 3, 'uma': 47, 'revisão': 10, 'de': 401, 'literatura': 7, 'resumo': 2, 'o': 108, 'data': 75, 'é': 36, 'um': 36, 'advento': 6, 'tecnológico': 1, 'processamento': 10, 'grandes': 4, 'volumes': 3, 'dados': 88, 'que': 99, 'vem': 6, 'ganhando': 2, 'notoriedade': 2, 'por': 31, 'conta': 1, 'oportunidades': 8, 'e': 155, 'desafios': 13, 'em': 87, 'torno': 2, 'sua': 12, 'utilidade': 2, 'no': 31, 'apoio': 5, 'aos': 13, 'negócios': 33, 'diante': 2, 'disso': 7, 'este': 12, 'artigo': 6, 'procura': 2, 'através': 9, 'sistemática': 4, 'da': 58, 'identificar': 2, 'como': 60, 'estão': 12, 'ligados': 6, 'mundo': 5, 'para': 72, 'isso': 3, 'são': 31, 'investigados': 1, '439': 4, 'artigos': 12, 'termos': 7, 'tipo': 2, 'publicação': 4, 'evolução': 6, 'anual': 2, 'produção': 17, 'principais': 12, 'autores': 19, 'instituições': 20, 'resultado': 4, 'foi': 15, 'identificado': 1, 'existe': 1, 'crescente': 5, 'interesse': 3, 'pelo': 6, 'tema': 11, 'ligado': 3, 'tanto': 4, 'nas': 15, 'produções': 18, 'ligadas': 5, 'às': 18, 'científicas': 3, 'quanto': 4, 'àquelas': 1, 'empresas': 30, 'também': 20, 'foram': 14, 'observadas': 1, 'ligações': 2, 'a': 150, 'gama': 2, 'bastante': 5, 'ampla': 1, 'marketing': 4, 'à': 19, 'saúde': 4, 'ou': 27, 'transporte': 2, 'público': 1, 'educação': 2, 'sempre': 1, 'melhor': 5, 'tomada': 13, 'decisão': 12, '1': 3, 'introdução': 1, 'na': 43, 'última': 2, 'década': 2, 'termo': 6, 'passou': 2, 'fazer': 2, 'parte': 4, 'dos': 34, 'repositórios': 3, 'científicos': 7, 'neste': 14, 'curto': 2, 'espaço': 2, 'tempo': 11, 'mídia': 2, 'algumas': 4, 'causando': 1, 'ora': 2, 'fascínio': 1, 'huwe': 1, '2012': 21, 'desconfiança': 1, 'davenport': 17, '2014': 36, 'pessoas': 2, 'gestão': 4, 'informação': 12, 'assim': 12, 'gestores': 1, 'corporativos': 3, 'novas': 5, 'sofisticadas': 2, 'ferramentas': 10, 'surgem': 1, 'cada': 6, 'dia': 2, 'melhorando': 1, 'desempenho': 3, 'diversos': 12, 'aspectos': 4, 'especialmente': 3, 'volume': 8, 'goldman': 1, 'kon': 1, 'pereira': 2, 'junior': 1, 'polato': 1, '&': 23, 'proposta': 2, 'utilização': 10, 'grande': 10, 'quantidade': 12, 'informações': 10, 'não': 26, 'novidade': 1, 'nem': 2, 'ciência': 1, 'administração': 1, 'remonta': 1, 'início': 2, 'maior': 14, 'sistemas': 9, 'pelas': 6, 'partir': 9, 'anos': 12, '1950': 2, 'chen': 14, 'chiang': 3, 'storey': 3, 'fenômeno': 2, 'destaque': 5, 'aumento': 3, 'fontes': 10, 'exógenas': 1, 'captadas': 1, 'redes': 4, 'sociais': 3, 'meios': 3, 'informatizados': 1, 'colaboração': 3, 'massa': 3, 'além': 12, 'sensores': 3, 'produtos': 4, 'registros': 2, 'tráfego': 1, 'internet': 8, 'entre': 19, 'outros': 11, 'esta': 15, 'imensa': 2, 'compõem': 1, 'característica': 4, 'fazendo': 2, 'referência': 3, 'grandiosidade': 2, 'ligada': 1, 'seu': 3, 'nome': 1, 'outras': 13, 'características': 7, 'variedade': 5, 'velocidade': 3, 'veracidade': 3, 'comumente': 1, 'citadas': 4, 'conforme': 5, 'demchenko': 2, 'grosso': 1, 'laat': 1, 'membrey': 1, '2013': 13, 'cresce': 2, 'possibilidade': 2, 'sentido': 8, 'maiores': 2, 'está': 6, 'análise': 10, 'destes': 5, 'compreensão': 2, 'eles': 4, 'podem': 10, 'melhorar': 1, 'os': 59, 'as': 45, 'aplicações': 8, 'áreas': 15, 'captados': 2, 'internamente': 1, 'sejam': 2, 'insuficientes': 1, 'possam': 2, 'ser': 15, 'completados': 1, 'externas': 1, 'provenientes': 4, 'promessa': 1, 'pode': 7, 'usada': 2, 'compreender': 3, 'clientes': 3, 'mercados': 1, 'concorrentes': 1, 'ambiente': 2, 'mercado': 2, 'impacto': 1, 'tecnologias': 2, 'até': 6, 'mesmo': 5, 'fornecedores': 1, 'marchand': 1, 'peppard': 1, '2013;': 2, 'mayer-schonberger': 1, 'cukier': 1, 'múltiplas': 2, 'possibilidades': 5, 'parece': 1, 'emergência': 3, 'deste': 11, 'tem': 4, 'com': 66, 'mas': 5, 'sendo': 4, 'abordada': 2, 'ligação': 5, 'comunidade': 1, 'científica': 4, 'busca': 10, 'desta': 8, 'resposta': 2, 'estudo': 14, 'sintetizar': 1, 'conceitos': 3, 'sobre': 10, 'suas': 7, 'relações': 2, 'progressão': 1, 'das': 19, 'publicações': 14, 'ví ...

# %%
import pandas as pd
import seaborn as sns
import matplotlib as mpl
import matplotlib.pyplot as plt

df = pd.DataFrame(mydict.items(),  columns=['word', 'count']).sort_values('count',ascending=False)
df = df[df['count'] > 4] # somente termos com mais de 4 ocorrências
# df = df.iloc[ np.int(len(df)/2) - 10 : np.int(len(df)/2) + 10 ] # para livros ou textos com muitos termos limita a um número mínimo de termos

plt.figure(figsize=(24,10))
mpl.style.use(['seaborn'])
sns.barplot(x=df.word,y=df['count'])
plt.xticks(rotation=90) 

plt.show()
